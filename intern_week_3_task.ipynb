# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaRoopa123/Intern-week--1/blob/main/intern_week_3_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-74560d9f-03f5-4848-a981-0b48adb730e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74560d9f-03f5-4848-a981-0b48adb730e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.to_csv("students_data_clean.csv", index=False)


from google.colab import files
files.download("students_data_clean.csv")

# %%
df.info()
df.isnull().sum()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Hours_Studied     45 non-null     float64
#  1   Attendance        45 non-null     float64
#  2   Gender            34 non-null     object
#  3   Parent_Education  36 non-null     object
#  4   Exam_Score        45 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 2.1+ KB
#    Hours_Studied  Attendance  Gender Parent_Education  Exam_Score
# 0           8.93        63.0  Female       Highschool       88.83
# 1           6.23        86.0     NaN              NaN       44.34
# 2           8.94        63.0     NaN              NaN       41.55
# 3           7.23        91.0     NaN        Bachelors       38.74
# 4           7.53        69.0   Other          Masters       80.55
# 5           5.51        70.0   Other        Bachelors       32.13
# ...

# %%
df.columns = df.columns.str.strip()


df.dropna(how='all', inplace=True)


df['Gender'].fillna('Unknown', inplace=True)
df['Parent_Education'].fillna('Unknown', inplace=True)


df['Gender'] = df['Gender'].str.title().str.strip()
df['Parent_Education'] = df['Parent_Education'].str.title().str.strip()


for col in ['Hours_Studied', 'Attendance', 'Exam_Score']:
    if df[col].isnull().sum() > 0:
        df[col].fillna(df[col].mean(), inplace=True)


df.drop_duplicates(inplace=True)


df.loc[df['Attendance'] > 100, 'Attendance'] = 100
df.loc[df['Attendance'] < 0, 'Attendance'] = np.nan
df['Attendance'].fillna(df['Attendance'].mean(), inplace=True)

print("✅ Dataset cleaned successfully!")
# Out:
# ✅ Dataset cleaned successfully!
# /tmp/ipython-input-2255886892.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna('Unknown', inplace=True)
# /tmp/ipython-input-2255886892.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.info()
df.describe()
df.isnull().sum()


print("Duplicate rows:", df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Hours_Studied     48 non-null     float64
#  1   Attendance        48 non-null     float64
#  2   Gender            48 non-null     object
#  3   Parent_Education  48 non-null     object
#  4   Exam_Score        48 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 2.2+ KB
# Duplicate rows: 0

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("students_data_dirty.csv")


df.head()
# Out:
#    Hours_Studied  Attendance  Gender Parent_Education  Exam_Score
# 0           8.93        63.0  Female       Highschool       88.83
# 1           6.23        86.0     NaN              NaN       44.34
# 2           8.94        63.0     NaN              NaN       41.55
# 3           7.23        91.0     NaN        Bachelors       38.74
# 4           7.53        69.0   Other          Masters       80.55
